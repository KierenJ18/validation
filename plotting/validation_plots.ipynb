# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak
import os
import textwrap
from packages.validation_functions import *
np.set_printoptions(threshold=np.inf)

# %%
path = "/vols/hyperk/users/kj4718/validation/analysed_results/hkfd_idod_id_e_v2/pgun_hkfd_idod_elneg_00000000-0000_rwcs_analysed_wcsimrootevent.root"
infile = uproot.open(path)


#checking the keys we wanted are there
infile.keys()
#infile["validation_per_event"].keys()
infile["validation_per_trigger"].keys()
#infile["validation_per_file"].keys()
# Out:
# ['eventnumber',
#  'triggernumber',
#  'triggertype',
#  'ndigihits',
#  'ntubeshitdigi',
#  'ndigihitstrigger',
#  'triggertime',
#  'digipeperdigi',
#  'digitimeperdigi',
#  'totaldigipe',
#  'totaldiginoisefrac',
#  'digipe',
#  'digitime',
#  'digitime_noise',
#  'digitime_photon',
#  'digitime_mix',
#  'digiplustriggertime',
#  'diginoisefrac']

# %%
iwcd_events = 100

# For IWCD ID muons
iwcd_id_mu_folder = "/vols/hyperk/users/kj4718/validation/analysed_results/iwcd_idod_id_mu_v2"
iwcd_id_mu_full_paths = sorted([os.path.join(iwcd_id_mu_folder, file) for file in os.listdir(iwcd_id_mu_folder) if file.endswith(".root")])

# For IWCD ID electrons
iwcd_id_e_folder = "/vols/hyperk/users/kj4718/validation/analysed_results/iwcd_idod_id_e_v2"
iwcd_id_e_full_paths = sorted([os.path.join(iwcd_id_e_folder, file) for file in os.listdir(iwcd_id_e_folder) if file.endswith(".root")])

iwcd_id_mu_per_event, iwcd_id_mu_per_trigger, iwcd_id_mu_per_file = load_validation_data(iwcd_id_mu_full_paths, iwcd_events)
iwcd_id_e_per_event, iwcd_id_e_per_trigger, iwcd_id_e_per_file = load_validation_data(iwcd_id_e_full_paths, iwcd_events)

iwcd_id_mu_cut = get_cut(iwcd_id_mu_per_event)
iwcd_id_e_cut = get_cut(iwcd_id_e_per_event)

iwcd_id_mu_cut_params= get_cut_params(iwcd_id_mu_per_event)
iwcd_id_e_cut_params= get_cut_params(iwcd_id_e_per_event)

# %%
# For IWCD OD muons
iwcd_od_mu_folder = "/vols/hyperk/users/kj4718/validation/analysed_results/iwcd_idod_od_mu_v2"
iwcd_od_mu_full_paths = sorted([os.path.join(iwcd_od_mu_folder, file) for file in os.listdir(iwcd_od_mu_folder) if file.endswith(".root")])

#For IWCD OD electrons
iwcd_od_e_folder = "/vols/hyperk/users/kj4718/validation/analysed_results/iwcd_idod_od_e_v2"
iwcd_od_e_full_paths = sorted([os.path.join(iwcd_od_e_folder, file) for file in os.listdir(iwcd_od_e_folder) if file.endswith(".root")])

iwcd_od_mu_per_event, iwcd_od_mu_per_trigger, iwcd_od_mu_per_file = load_validation_data(iwcd_od_mu_full_paths, iwcd_events)
iwcd_od_e_per_event, iwcd_od_e_per_trigger, iwcd_od_e_per_file = load_validation_data(iwcd_od_e_full_paths, iwcd_events) 

iwcd_od_mu_cut = get_cut(iwcd_od_mu_per_event)
iwcd_od_e_cut = get_cut(iwcd_od_e_per_event)

iwcd_od_mu_cut_params= get_cut_params(iwcd_od_mu_per_event)
iwcd_od_e_cut_params= get_cut_params(iwcd_od_e_per_event)

# %%
hkfd_events = 100

# # For HKFD ID muons
hkfd_id_mu_folder = "/vols/hyperk/users/kj4718/validation/analysed_results/hkfd_idod_id_mu_v2"
hkfd_id_mu_full_paths = sorted([os.path.join(hkfd_id_mu_folder, file) for file in os.listdir(hkfd_id_mu_folder) if file.endswith(".root")])

# For HKFD ID electrons
hkfd_id_e_folder = "/vols/hyperk/users/kj4718/validation/analysed_results/hkfd_idod_id_e_v2"
hkfd_id_e_full_paths = sorted([os.path.join(hkfd_id_e_folder, file) for file in os.listdir(hkfd_id_e_folder) if file.endswith(".root")])

hkfd_id_mu_per_event, hkfd_id_mu_per_trigger, hkfd_id_mu_per_file = load_validation_data(hkfd_id_mu_full_paths, hkfd_events)
hkfd_id_e_per_event, hkfd_id_e_per_trigger, hkfd_id_e_per_file = load_validation_data(hkfd_id_e_full_paths, hkfd_events)

hkfd_id_mu_cut = get_cut(hkfd_id_mu_per_event)
hkfd_id_e_cut = get_cut(hkfd_id_e_per_event)

hkfd_id_mu_cut_params= get_cut_params(hkfd_id_mu_per_event)
hkfd_id_e_cut_params= get_cut_params(hkfd_id_e_per_event)

# %%
# For HKFD OD muons
hkfd_od_mu_folder = "/vols/hyperk/users/kj4718/validation/analysed_results/hkfd_idod_od_mu_v2"
hkfd_od_mu_full_paths = sorted([os.path.join(hkfd_id_mu_folder, file) for file in os.listdir(hkfd_id_mu_folder) if file.endswith(".root")])

# For HKFD OD electrons
hkfd_od_e_folder = "/vols/hyperk/users/kj4718/validation/analysed_results/hkfd_idod_od_e_v2"
hkfd_od_e_full_paths = sorted([os.path.join(hkfd_od_e_folder, file) for file in os.listdir(hkfd_od_e_folder) if file.endswith(".root")])

hkfd_od_mu_per_event, hkfd_od_mu_per_trigger, hkfd_od_mu_per_file = load_validation_data(hkfd_od_mu_full_paths, hkfd_events)
hkfd_od_e_per_event, hkfd_od_e_per_trigger, hkfd_od_e_per_file = load_validation_data(hkfd_od_e_full_paths, hkfd_events)

hkfd_od_mu_cut = get_cut(hkfd_od_mu_per_event)
hkfd_od_e_cut = get_cut(hkfd_od_e_per_event)

hkfd_od_mu_cut_params= get_cut_params(hkfd_od_mu_per_event)
hkfd_od_e_cut_params= get_cut_params(hkfd_od_e_per_event)

# %%
# Function to apply ROOT-like styling
def apply_root_style():
    plt.style.use("default")  # Reset to default style
    plt.rcParams.update({
        "font.family": "serif",  # Use serif font like ROOT
        "font.size": 20,         # Increase font size
        "axes.labelsize": 16,    # Axis label size
        "axes.titlesize": 22,    # Title size
        "xtick.labelsize": 14,   # X-axis tick size
        "ytick.labelsize": 14,   # Y-axis tick size
        "grid.color": "gray",    # Grid color
        "grid.linestyle": "--",  # Dashed grid lines
        "grid.linewidth": 0.5,   # Grid line width
        "axes.grid": True,       # Enable grid
        "axes.edgecolor": "black",  # Axis edge color
        "axes.linewidth": 1.2,      # Axis line width
        "legend.fontsize": 15,      # Legend font size
        "legend.frameon": False,    # Remove legend frame
    })

# %%
# Plot histograms
#plot_histogram(cut_e_flat_e, "Energy (MeV)", "Energy Distribution")

apply_root_style()  # Apply styling

# plt.hist(iwcd_id_e_per_event["ntriggers"], bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons")
# plt.hist(iwcd_id_mu_per_event["ntriggers"], bins=50, histtype="step", color="red", linewidth=1.5, label="Muons")
# plt.xlabel("ntriggers")
# plt.ylabel("# Entries")
# plt.title("IWCD ntriggers")
# plt.yscale("log")
# plt.legend()
# plt.tight_layout()  
# plt.show()

fig, ax = plt.subplots(1, 2, figsize=(15, 6))
# Plot histograms for HKFD muons and electrons on same subplot 
ax[0].hist(hkfd_id_e_per_event["ntriggers"], bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons")
ax[0].hist(hkfd_id_mu_per_event["ntriggers"], bins=50, histtype="step", color="red", linewidth=1.5, label="Muons")
ax[0].set_xlabel("# Triggers", size=20)
ax[0].set_ylabel("# Entries", size=20)
ax[0].set_title("HKFD Triggers")
ax[0].set_yscale("log")
#ax[0].legend()

# Plot histograms for IWCD muons and electrons
ax[1].hist(iwcd_id_e_per_event["ntriggers"], bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons")
ax[1].hist(iwcd_id_mu_per_event["ntriggers"], bins=50, histtype="step", color="red", linewidth=1.5, label="Muons")
ax[1].set_xlabel("# Triggers", size=20)
#ax[1].set_ylabel("# Entries")
ax[1].set_title("IWCD Triggers")
ax[1].set_yscale("log")
ax[1].legend()
plt.tight_layout()
plt.show()

# %%
#For IWCD 250 events per root file -->  250x400 = 100,000 events
#For WCTE 1000 events per root file --> 1000x100 = 100,000 events
# # Flatten all fields in each array
#     flattened_per_event = {field: ak.flatten(per_event[field], axis=None) for field in per_event.fields}
#     flattened_per_trigger = {field: ak.flatten(per_trigger[field], axis=None) for field in per_trigger.fields}
#     flattened_per_file = {field: ak.flatten(per_file[field], axis=None) for field in per_file.fields}

# %%
apply_root_style()  # Apply styling

fig, ax = plt.subplots(1, 2, figsize=(15, 6))

ax[0].hist(iwcd_id_e_cut_params["energy"], bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons")
ax[0].hist(iwcd_id_mu_cut_params["energy"], bins=50, histtype="step", color="red", linewidth=1.5, label="Muons")
ax[0].set_xlabel("Energy MeV")
ax[0].set_ylabel("# Entries")
ax[0].set_title("IWCD Energy Distribution")


ax[1].hist(hkfd_id_e_cut_params["energy"], bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons")
ax[1].hist(hkfd_id_mu_cut_params["energy"], bins=50, histtype="step", color="red", linewidth=1.5, label="Muons")
ax[1].set_xlabel("Energy MeV")
ax[1].set_title("HKFD Energy Distribution")
ax[1].legend()
plt.show()

# %%
#Checking max and min energy
iwcd_id_e_energy = iwcd_id_e_cut_params["energy"]
np.min(iwcd_id_e_energy), np.max(iwcd_id_e_energy)
# Out:
# (np.float32(0.8889031), np.float32(1500.7631))

# %%
np.sum(iwcd_id_mu_per_trigger["ndigihits"]==0)
# Out:
# np.int64(23205)

# %%
flag = hkfd_id_mu_per_event["track_flag"]
parent_id = hkfd_id_mu_per_event["track_parentid"]

directions = hkfd_id_mu_per_event["track_dir"]
dir_x = ak.flatten(directions["fX"])
dir_y = ak.flatten(directions["fY"])
dir_z = ak.flatten(directions["fZ"])
cut = ak.flatten((parent_id == 0) & (flag >= 0), axis=None)

dirs = [dir_x, dir_y, dir_z]

# %%
apply_root_style()  # Apply styling

# # X, Y, Z Position Distributions
# for axis in ["pos_x", "pos_y", "pos_z"]:
#     plt.hist(iwcd_id_e_cut_params[axis], bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons")
#     plt.hist(iwcd_id_mu_cut_params[axis], bins=50, histtype="step", color="red", linewidth=1.5, label="Muons")
#     plt.xlabel(f"{axis[-1].upper()} Position (cm)")
#     plt.ylabel("# Entries")
#     plt.title(f"IWCD {axis[-1].upper()} Position Distribution")
#     plt.xticks(np.linspace(-max(iwcd_id_e_cut_params[axis]), max(iwcd_id_e_cut_params[axis]), 9), rotation=45)
#     plt.legend()
#     plt.tight_layout()
#     plt.show()

# ee = iwcd_id_e_cut_params["radial_sq"]/100**2
# mumu = iwcd_id_mu_cut_params["radial_sq"]/100**2

# iwcd_id_e_digit_hits = iwcd_id_e_per_trigger["ndigihits"]
# iwcd_id_mu_digit_hits = iwcd_id_mu_per_trigger["ndigihits"]


# c = iwcd_id_e_per_event["ntriggers"]==1
# d = iwcd_id_mu_per_event["ntriggers"]==1

# a = iwcd_id_e_digit_hits[c]==0
# b = iwcd_id_mu_digit_hits[d]==0

# # Radius^2
# plt.hist(mumu, bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons")
# plt.hist(ee, bins=50, histtype="step", color="red", linewidth=1.5, label="Muons")
# plt.xlabel("Radius$^2$ ($m^2$)")
# plt.ylabel("# Entries")
# plt.xticks(np.linspace(0, max(ee), 7), rotation=45)
# plt.title("IWCD Radial Dist$^2$ from Axis of Cylinder")
# plt.legend()
# plt.tight_layout()
# plt.show()


apply_root_style()  # Apply styling

# X, Y, Z Position Distributions
for axis in ["pos_x", "pos_y", "pos_z"]:
    fig, ax = plt.subplots(1, 2, figsize=(12, 5))
    ax[0].hist(hkfd_id_e_cut_params[axis], bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons")
    ax[0].hist(hkfd_id_mu_cut_params[axis], bins=50, histtype="step", color="red", linewidth=1.5, label="Muons")
    ax[0].set_xlabel(f"{axis[-1].upper()} Position (cm)")
    ax[0].set_ylabel("# Entries")
    ax[0].set_title(f"HKFD {axis[-1].upper()} Position Distribution")
    ax[0].set_xticks(np.linspace(-max(hkfd_id_e_cut_params[axis]), max(hkfd_id_e_cut_params[axis]), 9))
    for label in ax[0].get_xticklabels():
        label.set_rotation(45)

    ax[1].hist(iwcd_id_e_cut_params[axis], bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons")
    ax[1].hist(iwcd_id_mu_cut_params[axis], bins=50, histtype="step", color="red", linewidth=1.5, label="Muons")
    ax[1].set_xticks(np.linspace(-max(iwcd_id_e_cut_params[axis]), max(iwcd_id_e_cut_params[axis]), 9))
    for label in ax[1].get_xticklabels():
        label.set_rotation(45)
    ax[1].set_title(f"IWCD {axis[-1].upper()} Position Distribution")
    ax[1].set_xticks(np.linspace(-max(iwcd_id_e_cut_params[axis]), max(iwcd_id_e_cut_params[axis]), 9))
    for label in ax[1].get_xticklabels():
        label.set_rotation(45)

    ax[1].legend()
    plt.show()

ee = (hkfd_id_e_cut_params["pos_x"]**2 + hkfd_id_e_cut_params["pos_z"]**2)/100**2
mumu =(hkfd_id_mu_cut_params["pos_x"]**2 + hkfd_id_mu_cut_params["pos_z"]**2)/100**2

hkfd_id_e_digit_hits = hkfd_id_e_per_trigger["ndigihits"]
hkfd_id_mu_digit_hits = hkfd_id_mu_per_trigger["ndigihits"]


c = hkfd_id_e_per_event["ntriggers"]==1
d = hkfd_id_mu_per_event["ntriggers"]==1

a = hkfd_id_e_digit_hits[c]==0
b = hkfd_id_mu_digit_hits[d]==0

# Radius^2
plt.hist(ee, bins=50, histtype="step", color="Blue", linewidth=1.5, label="Electrons")
plt.hist(mumu, bins=50, histtype="step", color="red", linewidth=1.5, label="Muons")
plt.xlabel("Radius$^2$ ($m^2$)")
plt.ylabel("# Entries")
plt.xticks(np.linspace(0, max(ee), 7), rotation=45)
plt.title("HKFD Radial Dist$^2$ from Axis of Cylinder")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# # X Direction
# plt.hist(ak.to_numpy(cut_dir_x_flat_e), bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons")
# plt.hist(ak.to_numpy(cut_dir_x_flat_mu), bins=50, histtype="step", color="red", linewidth=1.5, label="Muons")
# plt.xlabel("X Direction")
# plt.ylabel("# Entries")
# plt.title("IWCD X Direction Distribution")
# plt.legend()
# plt.tight_layout()
# plt.show()

# # Y Direction
# plt.hist(ak.to_numpy(cut_dir_y_flat_e), bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons")
# plt.hist(ak.to_numpy(cut_dir_y_flat_mu), bins=50, histtype="step", color="red", linewidth=1.5, label="Muons")
# plt.xlabel("Y Direction")
# plt.ylabel("# Entries")
# plt.title("IWCD Y Direction Distribution")
# plt.legend()
# plt.tight_layout()
# plt.show()

# # Z Direction
# plt.hist(ak.to_numpy(cut_dir_z_flat_e), bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons")
# plt.hist(ak.to_numpy(cut_dir_z_flat_mu), bins=50, histtype="step", color="red", linewidth=1.5, label="Muons")
# plt.xlabel("Z Direction")
# plt.ylabel("# Entries")
# plt.title("IWCD Z Direction Distribution")
# plt.legend()
# plt.tight_layout()
# plt.show()

# # Azimuthal Angle
# plt.hist(ak.to_numpy(azimuth_e), bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons")
# plt.hist(ak.to_numpy(azimuth_mu), bins=50, histtype="step", color="red", linewidth=1.5, label="Muons")
# plt.xlabel("Azimuthal Angle (rad)")
# plt.ylabel("# Entries")
# plt.title("IWCD Azimuthal Angle Distribution")
# plt.legend()
# plt.tight_layout()
# plt.show()

# %%
import awkward as ak

def plot_double_histogram(data1, data2, data3, data4, key, xlabel, ylabel, title_l, title_r, labels, logscale=False):
    """
    Plots two side-by-side histograms for two pairs of datasets.

    Parameters:
        data1, data2: First subplot datasets (e.g., IWCD ID, IWCD OD)
        data3, data4: Second subplot datasets (e.g., HKFD ID, HKFD OD)
        key: The key to extract from each dataset (e.g., "ndigihits")
        xlabel, ylabel, title: Axis labels and main title (title will be used as a prefix)
        labels: List of four labels [label1, label2, label3, label4] for the legend
    """

    
    data1 = ak.to_numpy(ak.flatten(data1[key], axis=None))
    data2 = ak.to_numpy(ak.flatten(data2[key], axis=None))
    data3 = ak.to_numpy(ak.flatten(data3[key], axis=None))
    data4 = ak.to_numpy(ak.flatten(data4[key], axis=None))
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))

    # First subplot

    axes[0].hist(data1, bins=50, histtype="step", color="blue", linewidth=1.5, label=labels[0])
    axes[0].hist(data2, bins=50, histtype="step", color="red", linewidth=1.5, label=labels[1])

    axes[0].set_xlabel(xlabel)
    axes[0].set_ylabel(ylabel)
    axes[0].set_title(f"{title_l}")
    axes[0].legend()


    axes[1].hist(data3, bins=50, histtype="step", color="blue", linewidth=1.5, label=labels[2])
    axes[1].hist(data4, bins=50, histtype="step", color="red", linewidth=1.5, label=labels[3])
    
    axes[1].set_xlabel(xlabel)
    axes[1].set_title(f"{title_r}")
    axes[1].legend()

    plt.yscale("log" if logscale else "linear")
    plt.tight_layout()
    plt.show()

# %%
#Noise time
plot_double_histogram(iwcd_id_e_per_trigger, iwcd_id_mu_per_trigger,
                        hkfd_id_e_per_trigger, hkfd_id_mu_per_trigger,
                        "digitime_noise", "Digit Noise Time (ns)", "# Entries",
                        "IWCD ID Digit Noise Time", "HKFD ID Digit Noise Time", ["Electrons", "Muons", "Electrons", "Muons"], logscale=True
)

#Nose time written explicitly
iwcd_id_e_noise_time = ak.to_numpy(ak.flatten(iwcd_id_e_per_trigger["digitime_noise"]))
iwcd_id_mu_noise_time = ak.to_numpy(ak.flatten(iwcd_id_mu_per_trigger["digitime_noise"]))
hkfd_id_e_noise_time = ak.to_numpy(ak.flatten(hkfd_id_e_per_trigger["digitime_noise"]))
hkfd_id_mu_noise_time = ak.to_numpy(ak.flatten(hkfd_id_mu_per_trigger["digitime_noise"]))

plt.hist(iwcd_id_e_noise_time, bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons")
plt.hist(iwcd_id_mu_noise_time, bins=50, histtype="step", color="red", linewidth=1.5, label="Muons")
plt.xlabel("Digit Noise Time (ns)")
plt.ylabel("# Entries")
plt.title("IWCD ID Digit Noise Time")
plt.legend()
plt.yscale("log")
plt.tight_layout()
plt.show()

plt.hist(hkfd_id_e_noise_time, bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons")
plt.hist(hkfd_id_mu_noise_time, bins=50, histtype="step", color="red", linewidth=1.5, label="Muons")
plt.xlabel("Digit Noise Time (ns)")
plt.ylabel("# Entries")
plt.title("HKFD ID Digit Noise Time")
plt.legend()
plt.yscale("log")
plt.tight_layout()
plt.show()

# %%
plt.hist(hkfd_id_mu_per_trigger["ndigihits"], bins=50, histtype="step", color="blue", linewidth=1.5, label="Muons")
plt.show()

# %%
plot_double_histogram(
    iwcd_id_e_per_trigger, iwcd_od_e_per_trigger,
    hkfd_id_e_per_trigger, hkfd_od_e_per_trigger,
    "ndigihits", "Number of Digits", "# Entries",
    "IWCD ID Electron Digit Hits", "HKFD ID Electron Digit Hits", ["ID", "OD", "ID", "OD"]
)
#
plot_double_histogram(iwcd_id_mu_per_trigger, iwcd_od_mu_per_trigger,
                        hkfd_id_mu_per_trigger, hkfd_od_mu_per_trigger,
                        "ndigihits", "Number of Digits", "# Entries",
                        "IWCD ID Muon Digit Hits", "HKFD ID Muon Digit Hits", ["ID", "OD", "ID", "OD"]
)

#Digit total charge
plot_double_histogram(iwcd_id_e_per_trigger, iwcd_id_mu_per_trigger,
                        hkfd_id_e_per_trigger, hkfd_id_mu_per_trigger,
                        "totaldigipe", "Digit Total Charge", "# Entries",
                        "IWCD ID Electron Digit Total Charge", "HKFD ID Electron Digit Total Charge", ["Electrons", "Muons", "Electron", "Muons"], logscale=True
)

#Digit time
plot_double_histogram(iwcd_id_e_per_trigger, iwcd_id_mu_per_trigger,
                        hkfd_id_e_per_trigger, hkfd_id_mu_per_trigger,
                        "digitime_noise", "Digit Time (ns)", "# Entries",
                        "IWCD ID Electron Digit Time", "HKFD ID Electron Digit Time", ["Electrons", "Muons", "Electrons", "Muons"]
)

#Digit photon time
plot_double_histogram(iwcd_id_e_per_trigger, iwcd_id_mu_per_trigger,
                        hkfd_id_e_per_trigger, hkfd_id_mu_per_trigger,
                        "digitime_photon", "Digit Photon Time (ns)", "# Entries",
                        "IWCD ID Digit Photon Time", "HKFD ID Digit Photon Time", ["Electrons", "Muons", "Electrons", "Muons"], logscale=True
)

#Noise time
plot_double_histogram(iwcd_id_e_per_trigger, iwcd_id_mu_per_trigger,
                        hkfd_id_e_per_trigger, hkfd_id_mu_per_trigger,
                        "digitime_noise", "Digit Noise Time (ns)", "# Entries",
                        "IWCD ID Digit Noise Time", "HKFD ID Digit Noise Time", ["Electrons", "Muons", "Electrons", "Muons"], logscale=True
)
#Trigger hits
plot_double_histogram(iwcd_id_e_per_event, iwcd_id_mu_per_event,
                        hkfd_id_e_per_event, hkfd_id_mu_per_event,
                        "ntriggers", "Number of Triggers", "# Entries",
                        "IWCD ID Trigger Hits", "HKFD ID Trigger Hits", ["Electrons", "Muons", "Electrons", "Muons"], logscale=True
)
#Trigger time
plot_double_histogram(iwcd_id_e_per_trigger, iwcd_id_mu_per_trigger,
                        hkfd_id_e_per_trigger, hkfd_id_mu_per_trigger,
                        "triggertime", "Trigger Time (ns)", "# Entries",
                        "IWCD ID Trigger Time", "HKFD ID Trigger Time", ["Electrons", "Muons", "Electrons", "Muons"], logscale=True
)
#Digits+trigger time
plot_double_histogram(iwcd_id_e_per_trigger, iwcd_id_mu_per_trigger,
                        hkfd_id_e_per_trigger, hkfd_id_mu_per_trigger,
                        "digitime", "Digit Time (ns)", "# Entries",
                        "IWCD ID Digit Time", "HKFD ID Digit Time", ["Electrons", "Muons", "Electrons", "Muons"], logscale=True
)

#True hittime
plot_double_histogram(iwcd_id_e_per_event, iwcd_id_mu_per_event,
                        hkfd_id_e_per_event, hkfd_id_mu_per_event,
                        "hittime", "True Hit Time (ns)", "# Entries",
                        "IWCD ID True Hit Time", "HKFD ID True Hit Time", ["Electrons", "Muons", "Electrons", "Muons"], logscale=True
)

#Raw photon hittime
plot_double_histogram(iwcd_id_e_per_event, iwcd_id_mu_per_event,
                        hkfd_id_e_per_event, hkfd_id_mu_per_event,
                        "hittime_photon", "True Hit Time (ns)", "# Entries",
                        "IWCD ID True Hit Time", "HKFD ID True Hit Time", ["Electrons", "Muons", "Electrons", "Muons"], logscale=True
)

# %%
apply_root_style()  # Apply styling

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# IWCD Electron Digit Hits
axes[0].hist(iwcd_id_e_per_trigger["ndigihits"], bins=50, histtype="step", color="blue", linewidth=1.5, label="ID")
axes[0].hist(iwcd_od_e_per_trigger["ndigihits"], bins=50, histtype="step", color="red", linewidth=1.5, label="OD")
axes[0].set_xlabel("Digit Hits")
axes[0].set_ylabel("# Entries")
axes[0].set_title("IWCD Electron Digit Hits")
axes[0].legend()

# HKFD Electron Digit Hits
axes[1].hist(hkfd_id_e_per_trigger["ndigihits"], bins=50, histtype="step", color="blue", linewidth=1.5, label="ID")
axes[1].hist(hkfd_od_e_per_trigger["ndigihits"], bins=50, histtype="step", color="red", linewidth=1.5, label="OD")
axes[1].set_xlabel("Digit Hits")
axes[1].set_title("HKFD Electron Digit Hits")
axes[1].legend()

plt.tight_layout()
plt.show()

# Muon Digit Hits: IWCD (left) and HKFD (right)
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# IWCD Muon Digit Hits
axes[0].hist(iwcd_id_mu_per_trigger["ndigihits"], bins=50, histtype="step", color="blue", linewidth=1.5, label="ID")
axes[0].hist(iwcd_od_mu_per_trigger["ndigihits"], bins=50, histtype="step", color="red", linewidth=1.5, label="OD")
axes[0].set_xlabel("Digit Hits")
axes[0].set_ylabel("# Entries")
axes[0].set_title("IWCD Muon Digit Hits")
axes[0].legend()

# HKFD Muon Digit Hits
axes[1].hist(hkfd_id_mu_per_trigger["ndigihits"], bins=50, histtype="step", color="blue", linewidth=1.5, label="ID")
axes[1].hist(hkfd_od_mu_per_trigger["ndigihits"], bins=50, histtype="step", color="red", linewidth=1.5, label="OD")
axes[1].set_xlabel("Digit Hits")
axes[1].set_title("HKFD Muon Digit Hits")
axes[1].legend()

plt.tight_layout()
plt.show()

# Digit total Charge
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

ax[0].hist(hk_id_e_per_trigger["total_charge"], bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons", range=(0, 1000))
plt.hist(hk_id_mu_per_trigger["total_charge"], bins=50, histtype="step", color="red", linewidth=1.5, label="Muons", range=(0, 1000))
plt.xlabel("Digit Total Charge")
plt.ylabel("# Entries")
plt.title("IWCD Total Charge Distribution")
plt.legend()
plt.tight_layout()
plt.show()

# # Digit total Charge
plt.hist(ak.to_numpy(total_charge_e), bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons", range=(0, 1000))
# #plt.hist(ak.to_numpy(total_charge_mu), bins=50, histtype="step", color="red", linewidth=1.5, label="Muons", range=(0, 1000))
plt.xlabel("Digit Total Charge")
plt.ylabel("# Entries")
plt.title("HKFD Total Charge Distribution")
plt.legend()
plt.tight_layout()
plt.show()

# # # Digit Time
# # plt.hist(ak.to_numpy(digitime_e), bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons", density=True, range=(900, 1100))
# # #plt.hist(ak.to_numpy(digitime_mu), bins=50, histtype="step", color="red", linewidth=1.5, label="Muons",density=True, range=(900, 1100))
# # plt.xlabel("Digit Time (ns)")
# # plt.ylabel("Density of entries")
# # plt.title("IWCD Digit Time Distribution")
# # plt.legend()
# # plt.tight_layout()
# # plt.show()

# # Digit Photon Time
# plt.hist(ak.to_numpy(ak.flatten(iwcd_id_e_per_event["hittime_photon"])), bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons", density=True, range=(0,100))
# plt.hist(ak.to_numpy(ak.flatten(iwcd_id_mu_per_event["hittime_photon"])), bins=50, histtype="step", color="red", linewidth=1.5, label="Muons", density=True, range=(0,100))
# plt.xlabel("Digit Photon Time (ns)")
# plt.ylabel("Density of entries")
# plt.yscale("log")
# plt.title("IWCD Hit-time Photon Time (cutoff 100ns)")
# plt.legend()
# plt.tight_layout()
# plt.show()

# # # Digit Noise Time
# # plt.hist(ak.to_numpy(digit_noise_e), bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons")
# # #plt.hist(ak.to_numpy(digit_noise_mu), bins=50, histtype="step", color="red", linewidth=1.5, label="Muons")
# # plt.xlabel("Digit Noise Time (ns)")
# # plt.ylabel("# Entries")
# # plt.title("IWCD Digit Noise Time Distribution")
# # plt.legend()
# # plt.tight_layout()
# # plt.show()

# # # # Digit Mix Time
# # # plt.hist(ak.to_numpy(mix_e), bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons", range=(0, 60), density=True)
# # # plt.hist(ak.to_numpy(mix_mu), bins=50, histtype="step", color="red", linewidth=1.5, label="Muons", range=(0, 60), density=True)
# # # plt.xlabel("Digit Mix Time (ns)")
# # # plt.ylabel("# Entries")
# # # plt.title("Digit Mix Time Distribution")
# # # plt.legend()
# # # plt.tight_layout()
# # # plt.show()

# # # Digit Trigger Hits
# # plt.hist(iwcd_id_mu_per_trigger["ndigihitstrigger"], bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons")
# # #plt.hist(ak.to_numpy(digit_trigger_mu), bins=50, histtype="step", color="red", linewidth=1.5, label="Muons")
# # plt.xlabel("Digit Trigger Hits")
# # plt.ylabel("# Entries")
# # plt.title("IWCD Digit Trigger Hits Distribution")
# # plt.legend()
# # plt.tight_layout()
# # plt.show()

# # Trigger Time
# plt.hist(ak.to_numpy(iwcd_id_e_per_trigger["triggertime"]), bins=100, histtype="step", color="blue", linewidth=1.5, label="Electrons", range=(-2.2e9,-2.1e9))
# plt.hist(ak.to_numpy(iwcd_id_mu_per_trigger["triggertime"]), bins=100, histtype="step", color="red", linewidth=1.5, label="Muons", range=(-2.2e9,-2.1e9))
# plt.xlabel("Trigger Time (ns)")
# plt.ylabel("# Entries")
# plt.yscale("log")
# plt.title("WCTE Trigger Time Distribution")
# plt.legend()
# plt.tight_layout()
# plt.show()

# # # Digits + Trigger Time
# # plt.hist(ak.to_numpy(digiplus_triggertime_e), bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons")
# # #plt.hist(ak.to_numpy(digiplus_triggertime_mu), bins=50, histtype="step", color="red", linewidth=1.5, label="Muons")
# # plt.xlabel("Digits + Trigger Time (ns)")
# # plt.ylabel("# Entries")
# # plt.yscale("log")
# # plt.title("WCTE Digits + Trigger Time Distribution")
# # plt.legend()
# # plt.tight_layout()
# # plt.show()







apply_root_style()  # Apply styling







# # Digit Time
# plt.hist(ak.to_numpy(digitime_e), bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons", density=True, range=(900, 1100))
# #plt.hist(ak.to_numpy(digitime_mu), bins=50, histtype="step", color="red", linewidth=1.5, label="Muons",density=True, range=(900, 1100))
# plt.xlabel("Digit Time (ns)")
# plt.ylabel("Density of entries")
# plt.title("HKFD Digit Time Distribution")
# plt.legend()
# plt.tight_layout()
# plt.show()

# Digit Photon Time
plt.hist(ak.flatten(hkfd_id_e_per_event["hittime_photon"])/10**9, bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons")
# plt.hist(ak.to_numpy(ak.flatten(hkfd_id_mu_per_event["hittime_photon"])), bins=50, histtype="step", color="red", linewidth=1.5, label="Muons", density=True, range=(0,100))
plt.xlabel("Digit Photon Time (s)")
plt.ylabel("Entries")
plt.yscale("log")
plt.title("HKFD Photon Hit-Time")
plt.legend()
plt.tight_layout()
plt.show()

# # Digit Noise Time
# plt.hist(ak.to_numpy(digit_noise_e), bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons")
# #plt.hist(ak.to_numpy(digit_noise_mu), bins=50, histtype="step", color="red", linewidth=1.5, label="Muons")
# plt.xlabel("Digit Noise Time (ns)")
# plt.ylabel("# Entries")
# plt.title("HKFD Digit Noise Time Distribution")
# plt.legend()
# plt.tight_layout()
# plt.show()

# # # Digit Mix Time
# # plt.hist(ak.to_numpy(mix_e), bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons", range=(0, 60), density=True)
# # plt.hist(ak.to_numpy(mix_mu), bins=50, histtype="step", color="red", linewidth=1.5, label="Muons", range=(0, 60), density=True)
# # plt.xlabel("Digit Mix Time (ns)")
# # plt.ylabel("# Entries")
# # plt.title("Digit Mix Time Distribution")
# # plt.legend()
# # plt.tight_layout()
# # plt.show()

# # # Digit Trigger Hits
# # plt.hist(hkfd_id_mu_per_trigger["ndigihitstrigger"], bins=50, histtype="step", color="blue", linewidth=1.5, label="Muons")
# plt.hist(ak.to_numpy(digit_trigger_mu), bins=50, histtype="step", color="red", linewidth=1.5, label="Muons")
# plt.xlabel("Digit Trigger Hits")
# plt.ylabel("# Entries")
# plt.title("HKFD Digit Trigger Hits Distribution")
# plt.legend()
# plt.tight_layout()
# plt.show()

# Trigger Time
plt.hist(ak.to_numpy(hkfd_id_e_per_trigger["triggertime"]), bins=100, histtype="step", color="blue", linewidth=1.5, label="Electrons")
# plt.hist(ak.to_numpy(hkfd_id_mu_per_trigger["triggertime"]), bins=100, histtype="step", color="red", linewidth=1.5, label="Muons")
plt.xlabel("Trigger Time (ns)")
plt.ylabel("# Entries")
plt.yscale("log")
plt.title("HKFD Trigger Time Distribution")
plt.legend()
plt.tight_layout()
plt.show()

# # Digits + Trigger Time
# plt.hist(ak.to_numpy(digiplus_triggertime_e), bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons")
# #plt.hist(ak.to_numpy(digiplus_triggertime_mu), bins=50, histtype="step", color="red", linewidth=1.5, label="Muons")
# plt.xlabel("Digits + Trigger Time (ns)")
# plt.ylabel("# Entries")
# plt.yscale("log")
# plt.title("HKFD Digits + Trigger Time Distribution")
# plt.legend()
# plt.tight_layout()
# plt.show()

# %%
def make_cuts(e_per_trigger, e_per_event, e_cut_params, radial_sq_key="radial_sq", pos_x_key="pos_x", pos_y_key="pos_y", pos_z_key="pos_z", r_cut=325, y_cut=375):
    """
    Make selection cuts for a given particle species.
    
    Returns:
        - pos_x, pos_y, pos_z, pos_r for 0 digit hits (ntriggers==1)
        - pos_x_1, pos_y_1, pos_z_1, pos_r_1 for >=1 digit hits (ntriggers==1)
        - in_tank_r, in_tank_y masks for fiducial volume
    """
    e_digit_hits = e_per_trigger["ndigihits"]
    ntrig_mask = e_per_event["ntriggers"] == 1
    zero_dig_mask = e_digit_hits[ntrig_mask] == 0
    nonzero_dig_mask = np.logical_not(zero_dig_mask)

    pos_x = e_cut_params[pos_x_key][zero_dig_mask]
    pos_y = e_cut_params[pos_y_key][zero_dig_mask]
    pos_z = e_cut_params[pos_z_key][zero_dig_mask]
    pos_r = np.sqrt(e_cut_params[radial_sq_key][zero_dig_mask])

    pos_x_1 = e_cut_params[pos_x_key][nonzero_dig_mask]
    pos_y_1 = e_cut_params[pos_y_key][nonzero_dig_mask]
    pos_z_1 = e_cut_params[pos_z_key][nonzero_dig_mask]
    pos_r_1 = np.sqrt(e_cut_params[radial_sq_key][nonzero_dig_mask])

    in_tank_r = abs(pos_r) <= r_cut
    in_tank_y = abs(pos_y) <= y_cut

    return pos_x, pos_y, pos_z, pos_r, pos_x_1, pos_y_1, pos_z_1, pos_r_1, in_tank_r, in_tank_y

# %%
iwcd_id_e_digit_hits = iwcd_id_e_per_trigger["ndigihits"]
iwcd_id_mu_digit_hits = iwcd_id_mu_per_trigger["ndigihits"]

iwcd_od_e_digit_hits = iwcd_od_e_per_trigger["ndigihits"]
iwcd_od_mu_digit_hits = iwcd_od_e_per_trigger["ndigihits"]

c = iwcd_id_e_per_event["ntriggers"]==1
d = iwcd_id_mu_per_event["ntriggers"]==1

a = iwcd_id_e_digit_hits[c]==0
b = iwcd_id_mu_digit_hits[d]==0

i = np.logical_not(a)

e = iwcd_od_e_per_event["ntriggers"]==1
f = iwcd_od_mu_per_event["ntriggers"]==1

g = iwcd_od_e_digit_hits[e]==0
h = iwcd_od_mu_digit_hits[d]==0

# Electron selections (existing)
iwcd_id_cut_e_pos_x = iwcd_id_e_cut_params["pos_x"][a]
iwcd_id_cut_e_pos_y = iwcd_id_e_cut_params["pos_y"][a]
iwcd_id_cut_e_pos_z = iwcd_id_e_cut_params["pos_z"][a]
iwcd_id_cut_e_pos_r = np.sqrt(iwcd_id_e_cut_params["radial_sq"][a])

iwcd_id_cut_e_pos_x_1 = iwcd_id_e_cut_params["pos_x"][i]
iwcd_id_cut_e_pos_y_1 = iwcd_id_e_cut_params["pos_y"][i]
iwcd_id_cut_e_pos_z_1 = iwcd_id_e_cut_params["pos_z"][i]
iwcd_id_cut_e_pos_r_1 = np.sqrt(iwcd_id_e_cut_params["radial_sq"][i])

iwcd_od_cut_e_pos_x = iwcd_id_e_cut_params["pos_x"][g]
iwcd_od_cut_e_pos_y = iwcd_id_e_cut_params["pos_y"][g]
iwcd_od_cut_e_pos_z = iwcd_id_e_cut_params["pos_z"][g]
iwcd_od_cut_e_pos_r = np.sqrt(iwcd_id_e_cut_params["radial_sq"][g])

iwcd_id_e_in_tank_r = abs(iwcd_id_cut_e_pos_r)<=325
iwcd_id_e_in_tank_y = abs(iwcd_id_cut_e_pos_y)<=375

iwcd_od_e_in_tank_r = abs(iwcd_od_cut_e_pos_r)<=325
iwcd_od_e_in_tank_y = abs(iwcd_od_cut_e_pos_y)<=375

# # Muon selections (copy)
# iwcd_id_cut_mu_pos_x = iwcd_id_mu_cut_params["pos_x"][b]
# iwcd_id_cut_mu_pos_y = iwcd_id_mu_cut_params["pos_y"][b]
# iwcd_id_cut_mu_pos_z = iwcd_id_mu_cut_params["pos_z"][b]
# iwcd_id_cut_mu_pos_r = np.sqrt(iwcd_id_mu_cut_params["radial_sq"][b])

# iwcd_id_cut_mu_pos_x_1 = iwcd_id_mu_cut_params["pos_x"][~b]
# iwcd_id_cut_mu_pos_y_1 = iwcd_id_mu_cut_params["pos_y"][~b]
# iwcd_id_cut_mu_pos_z_1 = iwcd_id_mu_cut_params["pos_z"][~b]
# iwcd_id_cut_mu_pos_r_1 = np.sqrt(iwcd_id_mu_cut_params["radial_sq"][~b])

# # OD muon selection: use mask for ntriggers==1 and digit hits == 0
# # e is for electrons, so for muons, define f and h
# f = iwcd_od_mu_per_event["ntriggers"] == 1
# h = iwcd_od_mu_digit_hits[f] == 0

# iwcd_od_cut_mu_pos_x = iwcd_id_mu_cut_params["pos_x"][h]
# iwcd_od_cut_mu_pos_y = iwcd_id_mu_cut_params["pos_y"][h]
# iwcd_od_cut_mu_pos_z = iwcd_id_mu_cut_params["pos_z"][h]
# iwcd_od_cut_mu_pos_r = np.sqrt(iwcd_id_mu_cut_params["radial_sq"][h])

# iwcd_id_mu_in_tank_r = abs(iwcd_id_cut_mu_pos_r) <= 325
# iwcd_id_mu_in_tank_y = abs(iwcd_id_cut_mu_pos_y) <= 375

# iwcd_od_mu_in_tank_r = abs(iwcd_od_cut_mu_pos_r) <= 325
# iwcd_od_mu_in_tank_y = abs(iwcd_od_cut_mu_pos_y) <= 375





# # Muon selections for HKFD (no electron or OD results)
# hkfd_id_mu_digit_hits = hkfd_id_mu_per_trigger["ndigihits"]

# # Only keep events with ntriggers==1
# d = hkfd_id_mu_per_event["ntriggers"] == 1

# # Mask for events with zero digit hits
# b = hkfd_id_mu_digit_hits[d] == 0

# hkfd_id_cut_mu_pos_x = hkfd_id_mu_cut_params["pos_x"][b]
# hkfd_id_cut_mu_pos_y = hkfd_id_mu_cut_params["pos_y"][b]
# hkfd_id_cut_mu_pos_z = hkfd_id_mu_cut_params["pos_z"][b]
# hkfd_id_cut_mu_pos_r = np.sqrt(hkfd_id_mu_cut_params["radial_sq"][b])

# hkfd_id_cut_mu_pos_x_1 = hkfd_id_mu_cut_params["pos_x"][~b]
# hkfd_id_cut_mu_pos_y_1 = hkfd_id_mu_cut_params["pos_y"][~b]
# hkfd_id_cut_mu_pos_z_1 = hkfd_id_mu_cut_params["pos_z"][~b]
# hkfd_id_cut_mu_pos_r_1 = np.sqrt(hkfd_id_mu_cut_params["radial_sq"][~b])

# hkfd_id_mu_in_tank_r = abs(hkfd_id_cut_mu_pos_r) <= 325
# hkfd_id_mu_in_tank_y = abs(hkfd_id_cut_mu_pos_y) <= 375

# Electron and OD selections commented out for now
hkfd_id_e_digit_hits = hkfd_id_e_per_trigger["ndigihits"]
# hkfd_od_e_digit_hits = hkfd_od_e_per_trigger["ndigihits"]
# hkfd_od_mu_digit_hits = hkfd_od_e_per_trigger["ndigihits"]
c = hkfd_id_e_per_event["ntriggers"]==1
a = hkfd_id_e_digit_hits[c]==0
i = np.logical_not(a)
# e = hkfd_od_e_per_event["ntriggers"]==1
# g = hkfd_od_e_digit_hits[e]==0
hkfd_id_cut_e_pos_x = hkfd_id_e_cut_params["pos_x"][a]
hkfd_id_cut_e_pos_y = hkfd_id_e_cut_params["pos_y"][a]
hkfd_id_cut_e_pos_z = hkfd_id_e_cut_params["pos_z"][a]
hkfd_id_cut_e_pos_r = np.sqrt(hkfd_id_cut_e_pos_x**2 + hkfd_id_cut_e_pos_y**2)
hkfd_id_cut_e_pos_x_1 = hkfd_id_e_cut_params["pos_x"][i]
hkfd_id_cut_e_pos_y_1 = hkfd_id_e_cut_params["pos_y"][i]
hkfd_id_cut_e_pos_z_1 = hkfd_id_e_cut_params["pos_z"][i]
hkfd_id_cut_e_pos_r_1 = np.sqrt(hkfd_id_cut_e_pos_x_1**2 + hkfd_id_cut_e_pos_y_1**2)
# hkfd_od_cut_e_pos_x = hkfd_id_e_cut_params["pos_x"][g]
# hkfd_od_cut_e_pos_y = hkfd_id_e_cut_params["pos_y"][g]
# hkfd_od_cut_e_pos_z = hkfd_id_e_cut_params["pos_z"][g]
# hkfd_od_cut_e_pos_r = np.sqrt(hkfd_id_e_cut_params["radial_sq"][g])
hkfd_id_e_in_tank_r = abs(hkfd_id_cut_e_pos_r)<=3530
hkfd_id_e_in_tank_z = abs(hkfd_id_cut_e_pos_z)<=3260
# hkfd_od_e_in_tank_r = abs(hkfd_od_cut_e_pos_r)<=325
# hkfd_od_e_in_tank_y = abs(hkfd_od_cut_e_pos_y)<=375
# f = hkfd_od_mu_per_event["ntriggers"] == 1
# h = hkfd_od_mu_digit_hits[f] == 0
# hkfd_od_cut_mu_pos_x = hkfd_id_mu_cut_params["pos_x"][h]
# hkfd_od_cut_mu_pos_y = hkfd_id_mu_cut_params["pos_y"][h]
# hkfd_od_cut_mu_pos_z = hkfd_id_mu_cut_params["pos_z"][h]
# hkfd_od_cut_mu_pos_r = np.sqrt(hkfd_id_mu_cut_params["radial_sq"][h])
# hkfd_od_mu_in_tank_r = abs(hkfd_od_cut_mu_pos_r) <= 325
# hkfd_od_mu_in_tank_y = abs(hkfd_od_cut_mu_pos_y) <= 375

# %%
def plot_double_2dhistogram(data1, data2, data3, data4, xlabel, ylabel, clabel, title_l, title_r, labels, mask1=False, mask2=False, suptitle=None):

    fig, axes = plt.subplots(1, 2, figsize=(12, 5))
    if mask1 is not False:
        data1 = data1[mask1]
        data2 = data2[mask1]
    if mask2 is not False:
        data3 = data3[mask2]
        data4 = data4[mask2]
    # First subplot
    h0 = axes[0].hist2d(data1, data2, bins=(50,50), linewidth=1.5, label=labels[0])
    axes[0].set_xlabel(xlabel)
    axes[0].set_ylabel(ylabel)
    axes[0].set_title(f"{title_l}", size=16)

    # Second subplot
    h1 = axes[1].hist2d(data3, data4, bins=(50,50), label=labels[1])
    axes[1].set_xlabel(xlabel)
    axes[1].set_title(f"{title_r}", size=16)
    plt.grid(False)
    
    # Add colorbars for each subplot
    cbar0 = fig.colorbar(h0[3], ax=axes[0])

    cbar1 = fig.colorbar(h1[3], ax=axes[1])
    cbar1.ax.set_ylabel(clabel)
    
    if suptitle is not None:
        plt.tight_layout(rect=[0, 0, 1, 0.95])
        fig.suptitle(suptitle, fontsize=18, y=0.95)
    else:
        plt.tight_layout()
    plt.show()

# %%
#0 Digit Hits
iwcd_id_e_cuts = make_cuts(iwcd_id_e_per_trigger, iwcd_id_e_per_event, iwcd_id_e_cut_params)
iwcd_id_mu_cuts = make_cuts(iwcd_id_mu_per_trigger, iwcd_id_mu_per_event, iwcd_id_mu_cut_params)
hkfd_id_e_cuts = make_cuts(hkfd_id_e_per_trigger, hkfd_id_e_per_event, hkfd_id_e_cut_params)
hkfd_id_mu_cuts = make_cuts(hkfd_id_mu_per_trigger, hkfd_id_mu_per_event, hkfd_id_mu_cut_params)
plot_double_2dhistogram(
    ak.to_numpy(iwcd_id_e_cuts[0]), ak.to_numpy(iwcd_id_e_cuts[1]),
    ak.to_numpy(hkfd_id_e_cuts[0]), ak.to_numpy(hkfd_id_e_cuts[2]),
    "X Position (m)", "Y Position (m)", "# Entries",
    "IWCD ID Electron Position", "HKFD ID Electron Position",
    ["IWCD ID", "HKFD ID"], suptitle="0 Digit Hits Position Distribution",
)

# %%
# plt.hist2d(ak.to_numpy(iwcd_id_cut_e_pos_x), ak.to_numpy(iwcd_id_cut_e_pos_y), bins=(50,50), label="Electrons")
# plt.xlabel("X Position (cm)")
# plt.ylabel("Y Position (cm)")
# plt.title("IWCD ID Electron Position for 0 Digit Hits")
# plt.grid(False)
# cbar = plt.colorbar()
# cbar.ax.set_ylabel('# Entries')
# plt.show()

# plt.hist2d(ak.to_numpy(iwcd_id_cut_e_pos_x[iwcd_id_e_in_tank_r]), ak.to_numpy(iwcd_id_cut_e_pos_y[iwcd_id_e_in_tank_r]), bins=(50,50), label="Electrons")
# plt.xlabel("X Position (cm)")
# plt.ylabel("Y Position (cm)")
# plt.title("cutting out OD events")
# plt.grid(False)
# cbar = plt.colorbar()
# cbar.ax.set_ylabel('# Entries')
# plt.show()

# plt.hist2d(ak.to_numpy(iwcd_id_cut_e_pos_x), ak.to_numpy(iwcd_id_cut_e_pos_z), bins=(50,50), label="Electrons")
# plt.xlabel("X Position (cm)")
# plt.ylabel("Z Position (cm)")
# plt.title("IWCD ID Electron Position for 0 Digit Hits")
# plt.grid(False)
# cbar = plt.colorbar()
# cbar.ax.set_ylabel('# Entries')
# plt.show()

# plt.hist2d(ak.to_numpy(iwcd_id_cut_e_pos_x[iwcd_id_e_in_tank_y]), ak.to_numpy(iwcd_id_cut_e_pos_z[iwcd_id_e_in_tank_y]), bins=(50,50), label="Electrons")
# plt.xlabel("X Position (cm)")
# plt.ylabel("Z Position (cm)")
# plt.title("cutting out OD events")
# plt.grid(False)
# cbar = plt.colorbar()
# cbar.ax.set_ylabel('# Entries')
# plt.show()

# plt.hist2d(ak.to_numpy(iwcd_id_cut_e_pos_r), ak.to_numpy(iwcd_id_cut_e_pos_y), bins=(50,50), label="Electrons")
# plt.xlabel("r Position (cm)")
# plt.ylabel("Y Position (cm)")
# plt.title("IWCD ID Electron Position for 0 Digit Hits")
# plt.grid(False)
# cbar = plt.colorbar()
# cbar.ax.set_ylabel('# Entries')
# plt.show()

# cut_ry = np.logical_and(iwcd_id_e_in_tank_y, iwcd_id_e_in_tank_r)

# #true fiducial volume cut applied (all events should have hits 0), so zero digit hits expected
# plt.hist2d(ak.to_numpy(iwcd_id_cut_e_pos_r[cut_ry]), ak.to_numpy(iwcd_id_cut_e_pos_y[cut_ry]), bins=(50,50), label="Muons")
# plt.xlabel("r Position (cm)")
# plt.ylabel("Y Position (cm)")
# plt.title("Cutting out OD events")
# plt.grid(False)
# cbar = plt.colorbar()
# cbar.ax.set_ylabel('# Entries')
# plt.show()


# plt.hist2d(ak.to_numpy(iwcd_id_cut_e_pos_r_1), ak.to_numpy(iwcd_id_cut_e_pos_y_1), bins=(50,50), label="Electrons")
# plt.xlabel("r Position (cm)")
# plt.ylabel("Y Position (cm)")
# plt.title("1 or more Digit Hits")
# plt.grid(False)
# cbar = plt.colorbar()
# cbar.ax.set_ylabel('# Entries')
# plt.show()

# plt.hist2d(ak.to_numpy(iwcd_od_cut_e_pos_x), ak.to_numpy(iwcd_od_cut_e_pos_y), bins=(50,50), label="Electrons")
# plt.xlabel("X Position (cm)")
# plt.ylabel("Y Position (cm)")
# plt.title("IWCD OD Electron Position for 0 Digit Hits")
# plt.grid(False)
# cbar = plt.colorbar()
# cbar.ax.set_ylabel('# Entries')
# plt.show()

# plt.hist2d(ak.to_numpy(iwcd_od_cut_e_pos_x), ak.to_numpy(iwcd_od_cut_e_pos_z), bins=(50,50), label="Electrons")
# plt.xlabel("X Position (cm)")
# plt.ylabel("Z Position (cm)")
# plt.title("IWCD OD Electron Position for 0 Digit Hits")
# plt.grid(False)
# cbar = plt.colorbar()
# cbar.ax.set_ylabel('# Entries')
# plt.show()

# plt.hist2d(ak.to_numpy(iwcd_od_cut_e_pos_r), ak.to_numpy(iwcd_od_cut_e_pos_y), bins=(50,50), label="Electrons")
# plt.xlabel("r Position (cm)")
# plt.ylabel("Y Position (cm)")
# plt.title("IWCD OD Electron Position for 0 Digit Hits")
# plt.grid(False)
# cbar = plt.colorbar()
# cbar.ax.set_ylabel('# Entries')
# plt.show()

# iwcd_od_e_triggers = ak.to_numpy(iwcd_od_e_per_event["ntriggers"])
# iwcd_od_e_pmt_id = np.arange(len(iwcd_od_e_triggers))

# # plt.hist2d(iwcd_od_e_pmt_id, iwcd_od_e_triggers, bins=(50,50), label="Electrons")
# # plt.xlabel("PMT ID")
# # plt.ylabel("Number of digits")
# # plt.title("IWCD OD PMT ID vs # Digits")
# # plt.grid(False)
# # cbar = plt.colorbar()
# # cbar.ax.set_ylabel('# Entries')
# # plt.show()






plt.hist2d(ak.to_numpy(hkfd_id_cut_e_pos_x), ak.to_numpy(hkfd_id_cut_e_pos_y), bins=(50,50), label="Electrons")
plt.xlabel("X Position (cm)")
plt.ylabel("Y Position (cm)")
plt.title("HKFD ID Electron Position for 0 Digit Hits")
plt.grid(False)
cbar = plt.colorbar()
cbar.ax.set_ylabel('# Entries')
plt.show()

plt.hist2d(ak.to_numpy(hkfd_id_cut_e_pos_x[hkfd_id_e_in_tank_z]), ak.to_numpy(hkfd_id_cut_e_pos_y[hkfd_id_e_in_tank_z]), bins=(50,50), label="Electrons")
plt.xlabel("X Position (cm)")
plt.ylabel("Y Position (cm)")
plt.title("cutting out OD events")
plt.grid(False)
cbar = plt.colorbar()
cbar.ax.set_ylabel('# Entries')
plt.show()

plt.hist2d(ak.to_numpy(hkfd_id_cut_e_pos_x), ak.to_numpy(hkfd_id_cut_e_pos_z), bins=(50,50), label="Muons")
plt.xlabel("X Position (cm)")
plt.ylabel("Z Position (cm)")
plt.title("HKFD ID Electron Position for 0 Digit Hits")
plt.grid(False)
cbar = plt.colorbar()
cbar.ax.set_ylabel('# Entries')
plt.show()

plt.hist2d(ak.to_numpy(hkfd_id_cut_e_pos_x[hkfd_id_e_in_tank_r]), ak.to_numpy(hkfd_id_cut_e_pos_y[hkfd_id_e_in_tank_r]), bins=(50,50), label="Electrons")
plt.xlabel("X Position (cm)")
plt.ylabel("Z Position (cm)")
plt.title("cutting out OD events")
plt.grid(False)
cbar = plt.colorbar()
cbar.ax.set_ylabel('# Entries')
plt.show()

plt.hist2d(ak.to_numpy(hkfd_id_cut_e_pos_r), ak.to_numpy(hkfd_id_cut_e_pos_z), bins=(50,50), label="Electrons")
plt.xlabel("r Position (cm)")
plt.ylabel("Z Position (cm)")
plt.title("HKFD ID Electrons Position for 0 Digit Hits")
plt.grid(False)
cbar = plt.colorbar()
cbar.ax.set_ylabel('# Entries')
plt.show()

cut_rz = np.logical_and(hkfd_id_e_in_tank_z, hkfd_id_e_in_tank_r)

#true fiducial volume cut applied (all events should have hits 0), so zero digit hits expected
plt.hist2d(ak.to_numpy(hkfd_id_cut_e_pos_r[cut_rz]), ak.to_numpy(hkfd_id_cut_e_pos_y[cut_rz]), bins=(50,50), label="Muons")
plt.xlabel("r Position (cm)")
plt.ylabel("Z Position (cm)")
plt.title("Cutting out OD events")
plt.grid(False)
cbar = plt.colorbar()
cbar.ax.set_ylabel('# Entries')
plt.show()

# plt.hist2d(ak.to_numpy(iwcd_id_cut_e_pos_r_1), ak.to_numpy(iwcd_id_cut_e_pos_y_1), bins=(50,50), label="Electrons")
# plt.xlabel("r Position (cm)")
# plt.ylabel("Y Position (cm)")
# plt.title("1 or more Digit Hits")
# plt.grid(False)
# cbar = plt.colorbar()
# cbar.ax.set_ylabel('# Entries')
# plt.show()

# plt.hist2d(ak.to_numpy(iwcd_od_cut_e_pos_x), ak.to_numpy(iwcd_od_cut_e_pos_y), bins=(50,50), label="Electrons")
# plt.xlabel("X Position (cm)")
# plt.ylabel("Y Position (cm)")
# plt.title("IWCD OD Electron Position for 0 Digit Hits")
# plt.grid(False)
# cbar = plt.colorbar()
# cbar.ax.set_ylabel('# Entries')
# plt.show()

# plt.hist2d(ak.to_numpy(iwcd_od_cut_e_pos_x), ak.to_numpy(iwcd_od_cut_e_pos_z), bins=(50,50), label="Electrons")
# plt.xlabel("X Position (cm)")
# plt.ylabel("Z Position (cm)")
# plt.title("IWCD OD Electron Position for 0 Digit Hits")
# plt.grid(False)
# cbar = plt.colorbar()
# cbar.ax.set_ylabel('# Entries')
# plt.show()

# plt.hist2d(ak.to_numpy(iwcd_od_cut_e_pos_r), ak.to_numpy(iwcd_od_cut_e_pos_y), bins=(50,50), label="Electrons")
# plt.xlabel("r Position (cm)")
# plt.ylabel("Y Position (cm)")
# plt.title("IWCD OD Electron Position for 0 Digit Hits")
# plt.grid(False)
# cbar = plt.colorbar()
# cbar.ax.set_ylabel('# Entries')
# plt.show()

# iwcd_od_e_triggers = ak.to_numpy(iwcd_od_e_per_event["ntriggers"])
# iwcd_od_e_pmt_id = np.arange(len(iwcd_od_e_triggers))

# # plt.hist2d(iwcd_od_e_pmt_id, iwcd_od_e_triggers, bins=(50,50), label="Electrons")
# # plt.xlabel("PMT ID")
# # plt.ylabel("Number of digits")
# # plt.title("IWCD OD PMT ID vs # Digits")
# # plt.grid(False)
# # cbar = plt.colorbar()
# # cbar.ax.set_ylabel('# Entries')
# # plt.show()

# %%
plt.hist(iwcd_id_e_cut_params["energy"][cut_ry], bins=25, histtype="step", color="blue", linewidth=1.5, label="Electrons")
plt.hist(iwcd_id_mu_cut_params["energy"][cut_ry], bins=25, histtype="step", color="red", linewidth=1.5, label="Muons")
plt.xlabel("Energy MeV")
plt.ylabel("# Entries")
plt.title("IWCD Energy of 0 Digihits")
plt.legend()
plt.tight_layout()  
plt.show()

# %%
# # Charge per hit
# plt.hist(
#     ak.to_numpy(
#         ak.where(hits_e != 0, total_charge_e / hits_e, 0)
#     ),
#     bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons"
# )
# #plt.hist(ak.to_numpy(total_charge_mu/hits_mu), bins=50, histtype="step", color="red", linewidth=1.5, label="Muons")
# plt.xlabel("Charge per hit")
# plt.ylabel("# Entries")
# plt.title("Charge per hit Distribution")
# plt.legend()
# plt.tight_layout()
# plt.show()

# plt.plot(raw_e, hits_e[76:], 'o') 
# plt.show()

# %%
# Raw Hits
plt.hist(ak.to_numpy(raw_e), bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons")
#plt.hist(ak.to_numpy(raw_mu), bins=50, histtype="step", color="red", linewidth=1.5, label="Muons")
plt.xlabel("Raw Hits")
plt.ylabel("# Entries")
plt.title("IWCD Raw Hits Distribution")
plt.legend()
plt.tight_layout()
plt.show()

# All Hit Time
plt.hist(ak.to_numpy(hittime_e), bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons", range=(0, 60), density=True)
#plt.hist(ak.to_numpy(hittime_mu), bins=50, histtype="step", color="red", linewidth=1.5, label="Muons", range=(0, 60), density=True)
plt.xlabel("Hit Time (ns)")
plt.ylabel("Density of Entries")
plt.title("IWCD All Physics Hit Time Distribution")
plt.legend()
plt.tight_layout()
plt.show()

# Photon Hit Time
plt.hist(ak.to_numpy(hittime_photon_e), bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons", range=(0, 60), density=True)
#plt.hist(ak.to_numpy(hittime_photon_mu), bins=50, histtype="step", color="red", linewidth=1.5, label="Muons", range=(0, 60), density=True)
plt.xlabel("Photon Hit Time (ns)")
plt.ylabel("Density of Entries")
plt.title("IWCD all Photons Hit Time Distribution")
plt.legend()
plt.tight_layout()
plt.show()

# Noise Hit Time
plt.hist(ak.to_numpy(hittime_noise_e), bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons")
#plt.hist(ak.to_numpy(hittime_noise_mu), bins=50, histtype="step", color="red", linewidth=1.5, label="Muons")
plt.xlabel("Noise Hit Time (ns)")
plt.ylabel("# Entries")
plt.title("IWCD all Noise Hit Time Distribution")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Raw Hits
# ----> 2 plt.hist(ak.to_numpy(raw_e), bins=50, histtype="step", color="blue", linewidth=1.5, label="Electrons")
#       3 #plt.hist(ak.to_numpy(raw_mu), bins=50, histtype="step", color="red", linewidth=1.5, label="Muons")
#       4 plt.xlabel("Raw Hits")
#
# NameError: name 'raw_e' is not defined

# %%
plt.hist(iwcd_id_e_per_file["npmt20"], bins=50)
plt.show()
# plot_histogram(no_pmts_m_e, "Number of mPMTs",  "Number of mPMTs") 
# plot_histogram(no_pmts_od_e, "Number of OD PMTs", "Number of OD PMTs")
# plot_histogram(radius_e, "IWCD Cylinder Radius (cm)", "IWCD Cylinder Radius")
# plot_histogram(length_e, "IWCD Cylinder Length (cm)", "IWCD Cylinder Length")

# %%
from mpl_toolkits.mplot3d import Axes3D  # Import 3D plotting module

# Define cylinder parameters
cylinder_height = 1000
cylinder_radius = 440

# Generate data for the cylinder
z_cylinder = np.linspace(-cylinder_height / 2, cylinder_height / 2, 100)
theta = np.linspace(0, 2 * np.pi, 100)
theta_grid, z_grid = np.meshgrid(theta, z_cylinder)
x_cylinder = cylinder_radius * np.cos(theta_grid)
y_cylinder = cylinder_radius * np.sin(theta_grid)

# Plot the cylinder
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x_cylinder, y_cylinder, z_grid, alpha=0.5, rstride=5, cstride=5, color='blue', edgecolor='k')

# Set axis labels and limits
ax.set_xlabel('X (cm)', fontsize=16)
ax.set_ylabel('Y (cm)', fontsize=16)
ax.set_zlabel('Z (cm)', fontsize=16)
ax.set_xlim(-cylinder_radius, cylinder_radius)
ax.set_ylim(-cylinder_radius, cylinder_radius)
ax.set_zlim(-cylinder_height / 2, cylinder_height / 2)
plt.tight_layout()

plt.show()

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')

# Plot the 3D scatter plot
ax.scatter(cut_z_flat[0:3000], cut_x_flat[0:3000], cut_y_flat[0:3000], alpha=0.5, label="Scatter Points")

# Plot the cylinder
ax.plot_surface(x_cylinder, y_cylinder, z_grid, alpha=0.1, rstride=5, cstride=5, color='yellow', edgecolor='k', label="Cylinder Surface")
# Set axis labels and limits
ax.set_xlim(-500, 500)
ax.set_ylim(-500, 500)
ax.set_zlim(-500, 500)
ax.set_xlabel('Z (cm)', fontsize=16)
ax.set_ylabel('X (cm)', fontsize=16)
ax.set_zlabel('Y (cm)', fontsize=16)

# Add legend
ax.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Apply ROOT-like styling
plt.style.use("default")
plt.rcParams.update({
    "font.family": "serif",  # Use serif font like ROOT
    "font.size": 14,         # Increase font size
    "axes.labelsize": 16,    # Axis label size
    "axes.titlesize": 18,    # Title size
    "xtick.labelsize": 14,   # X-axis tick size
    "ytick.labelsize": 14,   # Y-axis tick size
    "grid.color": "gray",    # Grid color
    "grid.linestyle": "--",  # Dashed grid lines
    "grid.linewidth": 0.5,   # Grid line width
    "axes.grid": True,       # Enable grid
    "axes.edgecolor": "black",  # Axis edge color
    "axes.linewidth": 1.2,      # Axis line width
    "legend.fontsize": 12,      # Legend font size
    "legend.frameon": False,    # Remove legend frame
})

uncorr_res = [10.42, 11.96, 13.35, 13.84, 13.90]
corr_res = [7.72, 9.70, 10.78, 12.22, 14.43]
rel_res = [5.81, 3.48, 7.80, 6.82, 9.32]
v_res = [9.80, 12.69, 11.62, 12.22, 18.31]
x_labels = ['0mm', '0.8mm', '1.6mm', '2mm', '3mm']
x = np.arange(len(x_labels))

fig, ax = plt.subplots(figsize=(10, 6))

#ax.plot(x, uncorr_res, 'o-', label='Uncorrected Uniformity Spread')
ax.plot(x, corr_res, 's-', label='Corrected Uniformity Spread', color='blue')
ax.plot(x, rel_res, 'd-', label='Relative Uniformity Spread', color='red')
#ax.plot(x, v_res, 'd-', label='Uniformity rel to V spread')

ax.set_xticks(x)
ax.set_xticklabels(x_labels)
ax.set_xlabel('Acrylic Rod Configuration', size=20)
ax.set_ylabel('Uniformity metric', size=20)
ax.legend(prop={'size': 15})
ax.set_title('Resolution Comparison', size=20)
ax.set_ylim(0,20)
plt.savefig("resolution_comparison.pdf") 
plt.show()
